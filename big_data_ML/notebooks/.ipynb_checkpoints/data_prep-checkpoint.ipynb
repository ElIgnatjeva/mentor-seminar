# %%
# !pip install psycopg2-binary sqlalchemy minio loguru
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp311-cp311-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (4.9 kB)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.11/site-packages (2.0.22)
# Collecting minio
#   Downloading minio-7.2.20-py3-none-any.whl.metadata (6.5 kB)
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy) (3.0.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from minio) (23.1.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from minio) (2023.7.22)
# Collecting pycryptodome (from minio)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (3.4 kB)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.11/site-packages (from minio) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->minio) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->minio) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio) (2.21)
# Downloading psycopg2_binary-2.9.12-cp311-cp311-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 802.6 kB/s eta 0:00:0000:0100:01
# Downloading minio-7.2.20-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 458.8 kB/s eta 0:00:00a 0:00:01
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 221.2 kB/s eta 0:00:00a 0:00:01
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 368.9 kB/s eta 0:00:0000:0100:01
# Installing collected packages: pycryptodome, psycopg2-binary, loguru, minio
# Successfully installed loguru-0.7.3 minio-7.2.20 psycopg2-binary-2.9.12 pycryptodome-3.23.0

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import psycopg2

def get_postgres_engine():
    """Прямое подключение к PostgreSQL"""
    conn_string = "postgresql://analytics_user:analytics_pass@postgres:5432/analytics_db"
    engine = create_engine(conn_string)
    return engine

engine = get_postgres_engine()

# %%
from minio import Minio
from minio.error import S3Error
import io

def get_minio_client():
    """Создание клиента MinIO"""
    client = Minio(
        "minio:9000",
        access_key="minioadmin",
        secret_key="minioadmin123",
        secure=False 
    )
    return client

client = get_minio_client()

# %%
def load_to_minio(df, bucket, path):
    parquet_buffer = io.BytesIO()
    df.to_parquet(parquet_buffer, index=False)
    parquet_buffer.seek(0)
    client.put_object(
        bucket,
        path,
        parquet_buffer,
        length=parquet_buffer.getbuffer().nbytes,
        content_type='application/parquet'
    )
    logger.info(f"Saved to MinIO: {parquet_path} {len(df)} rows")

# %%
"""Загрузка справочника скважин в MinIO"""
from datetime import datetime
from loguru import logger

engine = get_postgres_engine()

try:
    query = "SELECT * FROM staging.wells"
    df = pd.read_sql(query, engine)
    logger.info(f"Extracted {len(df)} wells from PostgreSQL")
                    
    parquet_path = f"oil_gas/wells/wells_{datetime.now().strftime('%Y%m%d')}.parquet"
    load_to_minio(df, "raw-data", parquet_path)
            
except Exception as e:
    logger.error(f"Failed to load wells: {e}")
    raise
# Out:
# 2026-05-16 17:32:35.275 | INFO     | __main__:<module>:10 - Extracted 5 wells from PostgreSQL
# 2026-05-16 17:32:35.284 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows

# %%
"""Загрузка данных добычи с партиционированием по дате"""
try:
    query = """
    SELECT 
        p.*,
        w.name as well_name,
        w.field_name,
        w.region,
        w.operator,
        w.status as well_status
    FROM staging.production p
    JOIN staging.wells w ON p.well_id = w.well_id
    ORDER BY p.date, p.well_id
    """
            
    df = pd.read_sql(query, engine)
    logger.info(f"Extracted {len(df)} production records from PostgreSQL")
        
    df['date'] = pd.to_datetime(df['date'])
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['day'] = df['date'].dt.day
            
    for date, group_df in df.groupby('date'):
        partition_path = f"oil_gas/production/date={date.strftime('%Y-%m-%d')}/production.parquet"
        save_df = group_df.drop(['year', 'month', 'day'], axis=1)
        load_to_minio(save_df, "raw-data", partition_path)
                    
    full_path = f"oil_gas/production/full_production_{datetime.now().strftime('%Y%m%d')}.parquet"
    load_to_minio(df, "raw-data", full_path)
            
    unique_dates = df['date'].nunique()
    logger.info(f"✓ Partitioned by {unique_dates} unique dates")
            
except Exception as e:
    logger.error(f"Failed to load production data: {e}")
    raise
# Out:
# 2026-05-16 17:33:30.398 | INFO     | __main__:<module>:17 - Extracted 150 production records from PostgreSQL
# 2026-05-16 17:33:30.410 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.416 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.421 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.426 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.431 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.435 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.439 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.444 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.447 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.457 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.462 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.465 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.468 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.472 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.475 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.479 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.483 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.486 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.490 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.494 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.497 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.501 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.504 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.507 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.511 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.514 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.517 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.521 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.525 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.528 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 5 rows
# 2026-05-16 17:33:30.532 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 150 rows
# 2026-05-16 17:33:30.533 | INFO     | __main__:<module>:33 - ✓ Partitioned by 30 unique dates

# %%
    """Загрузка телеметрии с партиционированием по дате"""

    try:
        # Чтение данных из PostgreSQL
        query = """
        SELECT 
            t.*,
            w.name as well_name,
            w.field_name,
            w.region,
            w.operator
        FROM staging.well_telemetry t
        JOIN staging.wells w ON t.well_id = w.well_id
        ORDER BY t.timestamp
        """
            
        df = pd.read_sql(query, engine)
        logger.info(f"Extracted {len(df)} telemetry records from PostgreSQL")
            
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        df['date'] = df['timestamp'].dt.date
        df['year'] = df['timestamp'].dt.year
        df['month'] = df['timestamp'].dt.month
        df['day'] = df['timestamp'].dt.day
        df['hour'] = df['timestamp'].dt.hour
            
        for date, group_df in df.groupby('date'):
            partition_path = f"oil_gas/telemetry/date={date}/telemetry.parquet"
            save_df = group_df.drop(['year', 'month', 'day', 'hour'], axis=1)
            load_to_minio(save_df, "raw-data", partition_path)
            
        unique_dates = df['date'].nunique()
        logger.info(f"✓ Partitioned by {unique_dates} unique dates")
        logger.info(f"✓ Total records: {len(df)}")
            
    except Exception as e:
        logger.error(f"Failed to load telemetry data: {e}")
        raise
# Out:
# 2026-05-16 17:35:33.426 | INFO     | __main__:<module>:18 - Extracted 48 telemetry records from PostgreSQL
# 2026-05-16 17:35:33.441 | INFO     | __main__:load_to_minio:12 - Saved to MinIO: oil_gas/wells/wells_20260516.parquet 48 rows
# 2026-05-16 17:35:33.442 | INFO     | __main__:<module>:33 - ✓ Partitioned by 1 unique dates
# 2026-05-16 17:35:33.442 | INFO     | __main__:<module>:34 - ✓ Total records: 48
