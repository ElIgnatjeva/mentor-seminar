# %%
# !pip install pymysql

# %%
import pymysql
import os

conn = pymysql.connect(
    host="db",
    port=3306,
    user="myapp_user",
    passwd="userpassword",
    db="myapp_db",
    charset='utf8mb4')

cur = conn.cursor()
cur.execute("select @@version")
output = cur.fetchall()
print(output)
